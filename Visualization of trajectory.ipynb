# %%
import pandas 
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt; #plt.rcdefaults()

# %%
dataframe = pandas.read_csv("trajectory.csv", header=None)
dataset = dataframe.values
X1 = dataset[:,0:1]
X2 = dataset[:,1:2]
X3 = dataset[:,2:3]
X4 = dataset[:,3:4]
X5 = dataset[:,4:5]

# %%
dataframenew = pandas.read_csv("trajectorymodi.csv", header=None)
dataset = dataframenew.values
Y1 = dataset[:,0:1]
Y2 = dataset[:,1:2]
Y3 = dataset[:,2:3]
Y4 = dataset[:,3:4]
Y5 = dataset[:,4:5]
t = np.arange(0, 847, 1)

# %%
dataframetruth = pandas.read_csv("truth.csv", header=None)
dataset = dataframetruth.values
Z1 = dataset[:,0:1]
Z2 = dataset[:,1:2]
Z3 = dataset[:,2:3]
Z4 = dataset[:,3:4]
Z5 = dataset[:,4:5]

# %%
print(Y2.shape)
print(X1.shape)
# Out:
# (847, 1)
# (847, 1)

# %%
plt.plot(t, X1, color='g',label="using_all_joint_parameters")
plt.plot(t, Y1, color='orange', label="after_removing_some_parameters")
plt.plot(t, Z1,color='r' ,label="truth")
plt.xlabel('time')
plt.ylabel('joint1_in_Nm')
#plt.legend(bbox_to_anchor=(1.0, 1.0))
#plt.title('j')

plt.show()

# %%
plt.plot(t, X2, color='g',label="using_all_joint_parameters")
plt.plot(t, Y2, color='orange', label="after_removing_some_parameters")
plt.plot(t, Z2,color='r' ,label="truth")
plt.xlabel('time')
plt.ylabel('joint2_in_Nm')
#plt.title('j')

plt.show()

# %%
plt.plot(t, X3, color='g',label="using_all_joint_parameters")
plt.plot(t, Y3, color='orange', label="after_removing_some_parameters")
plt.plot(t, Z3,color='r' ,label="truth")
plt.xlabel('time')
plt.ylabel('joint3_in_Nm')
#plt.title('j')

plt.show()

# %%
plt.plot(t, X4, color='g',label="using_all_joint_parameters")
plt.plot(t, Y4, color='orange', label="after_removing_some_parameters")
plt.plot(t, Z4,color='r' ,label="truth")
plt.xlabel('time')
plt.ylabel('joint4_in_Nm')
#plt.title('j')

plt.show()

# %%
plt.plot(t, X5, color='g',label="using_all_joint_parameters")
plt.plot(t, Y5, color='orange', label="after_removing_some_parameters")
plt.plot(t, Z5,color='r' ,label="truth")
plt.xlabel('time')
plt.ylabel('joint5_in_Nm')
plt.legend(bbox_to_anchor=(1.0, 1.0))
#plt.title('j')

plt.show()

# %%
objects = ('with_all_joint_parameters','after_removing_redundant_parameters')
y_pos = np.arange(len(objects))
performance = [0.02373,0.018894]
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('test_error')
plt.title('Error_comparison')
 
plt.show()

# %%
objects = ('with_all_joint_parameters','after_removing_redundant_parameters')
y_pos = np.arange(len(objects))
performance = [1874.1631,1853.288]
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Computational_time_in_sec')
plt.title('Computational_time_required')
 
plt.show()
